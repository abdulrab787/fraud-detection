# %%
from preprocessing.preprocessing import preprocess_data


X_train, X_val, y_train, y_val, X_test = preprocess_data(
    "../data/raw/Train.csv",
    "../data/raw/Test.csv"
)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# Numeric cols: ['id', 'feat1', 'feat2', 'feat3', 'feat4', 'feat5', 'feat6', 'feat7', 'feat8', 'feat9', 'feat10', 'feat11', 'feat12', 'feat13', 'feat14', 'feat15', 'feat16', 'feat17', 'feat18', 'feat19', 'feat20', 'feat21', 'feat22', 'feat23', 'feat24', 'feat25', 'feat26', 'feat27', 'feat28', 'Transaction_Amount']
# Categorical cols: []
# Fitting preprocessing pipeline...
# Preprocessing complete. Saved preprocessor.pkl
# (120000, 30) (30000, 30) (69129, 30)
